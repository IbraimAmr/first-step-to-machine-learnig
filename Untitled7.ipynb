# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv(r'kc_house_data.csv',encoding="ISO-8859-1",sep=',')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.isnull().sum().sum()#no missing data
# Out:
# 0

# %%
df.drop(['id','date','zipcode','grade','lat','long','waterfront','view'], axis=1,inplace=True)
df.head()
#to determine the prices of the houses ,number of bedrooms,bathrooms,the area of living , the space of the floor, 
#view , waterfront, year of built,year of renovated is important to determine the price of the houses
#but the waterfront, view will not be affect as they cannot be presented as numerical values"""
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  condition  \
# 0  221900.0         3       1.00         1180      5650     1.0          3
# 1  538000.0         3       2.25         2570      7242     2.0          3
# 2  180000.0         2       1.00          770     10000     1.0          3
# 3  604000.0         4       3.00         1960      5000     1.0          5
# 4  510000.0         3       2.00         1680      8080     1.0          3
#
#    sqft_above  sqft_basement  yr_built  yr_renovated  sqft_living15  \
# 0        1180              0      1955             0           1340
# 1        2170            400      1951          1991           1690
# 2         770              0      1933             0           2720
# 3        1050            910      1965             0           1360
# 4        1680              0      1987             0           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503

# %%
#it is not possible that the floor number is decimal , number of the floor is integer 
df = df.drop(df.index[df['floors'].isin([1.5,2.5,3.5])])
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0              3        1180              0      1955             0
# ...

# %%
#this barplot shows the number of units in the according to the floor number 
import seaborn as sns
sns.countplot(x='floors',data=df)
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2]), [Text(0, 0, '1.0'), Text(1, 0, '2.0'), Text(2, 0, '3.0')])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics
import numpy as np

y=df['bedrooms']
x=df['price']
x=df["price"].values[:,np.newaxis]
y=df["bedrooms"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=30)

# %%
model=LinearRegression()   #build linear regression model
model.fit(x_train,y_train)  #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance

# %%
print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 0.7246669821096978
# R squared 0.10628547224666351

# %%
plt.scatter(x,y,color="r")
plt.title("Linear Regression")
plt.ylabel("bedrooms")
plt.xlabel("price")
plt.plot(x,model.predict(x),color="k")
plt.show()
"""Here is the linear regression  where it predict the price of the house according to the number of bedrooms it contains.
,so when the model receive an input with specific number of bedrooms , the model will predict it's price"""
# Out:
# "Here is the linear regression  where it predict the price of the house according to the number of bedrooms it contains.\n,so when the model receive an input with specific number of bedrooms , the model will predict it's price"

# %%
df["bathrooms"]
x=df[["price","bathrooms"]]  
y=df["bedrooms"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) 

model=LinearRegression() 
model.fit(x_train,y_train) 
predicted=model.predict(x_test)

# %%
"""import seaborn as sns
sns.set_theme()

# Load the penguins dataset
var = sns.load_dataset('kc_house_data')

# Plot sepal width as a function of sepal_length across days
g = sns.lmplot(
    df=var,
    x="bedrooms", y="bathrooms", hue="price",
    height=5
)

# Use more informative axis labels than are provided by default
g.set_axis_labels("bedrooms", "bathrooms")"""
# Out:
# 'import seaborn as sns\nsns.set_theme()\n\n# Load the penguins dataset\nvar = sns.load_dataset(\'kc_house_data\')\n\n# Plot sepal width as a function of sepal_length across days\ng = sns.lmplot(\n    df=var,\n    x="bedrooms", y="bathrooms", hue="price",\n    height=5\n)\n\n# Use more informative axis labels than are provided by default\ng.set_axis_labels("bedrooms", "bathrooms")'

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures 
x= df[["bedrooms", "bathrooms"]]
y= df["price"].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=40)  #splitting data
lg=LinearRegression()
poly=PolynomialFeatures(degree=3)

x_train_fit = poly.fit_transform(x_train) #transforming our input data
lg.fit(x_train_fit, y_train)
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)

print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  82778163975.14499
# R squared:  0.35535209864463646

# %%
x= df["price"].values.reshape(-1,1)
y= df["bedrooms"].values
poly = PolynomialFeatures(degree = 2) 
x_poly = poly.fit_transform(x) 
poly.fit(x_poly, y) 
lg=LinearRegression()
lg.fit(x_poly, y) 

plt.scatter(x, y, color="r")
plt.title("Polynomial regression")
plt.ylabel("bedrooms")
plt.xlabel("price")
plt.plot(x, lg.predict(poly.fit_transform(x)), color="k")
